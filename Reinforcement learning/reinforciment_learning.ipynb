# %% [markdown]
# #  Epsilon Greedy faz?

# %% [markdown]
# Esse modelo se concentra em duas abordagens: Imagine que voce esta em uma sorveteria, e precisa definir seu sabor favorito.
#
# Experimentar algo novo: Provar um sabor que você nunca experimentou antes (como sorvete de manga!).
#
# Escolher o que já conhece e gosta: Pegar seu favorito, como chocolate, porque sabe que é bom.
#
# Por que isso é importante?
# Se você só pegar chocolate, pode estar perdendo outros sabores incríveis. Mas se só experimentar novos, talvez nunca aproveite o chocolate que já ama. Então, o computador (ou você, na loja) precisa equilibrar essas escolhas!
#
# Como ele decide?
# O algoritmo usa uma coisinha chamada Epsilon (ε). Imagine que o Epsilon é uma moedinha mágica:
#
# Quando jogamos a moeda e dá "cara", provamos um sabor novo (exploração 🍋).
# Quando dá "coroa", escolhemos nosso favorito de sempre (exploração de conhecimento 🍫).
# No começo, Epsilon ajuda a experimentar bastante, mas depois ele vai deixando você aproveitar o que já sabe que é bom.
#
# Onde isso é usado?
# Esse método é usado em várias coisas legais, como:
#
# YouTube: Para decidir quais vídeos recomendar para você.
# Jogos: Para ensinar robôs a jogar melhor.
# Compras online: Para mostrar produtos que você pode gostar.
# Vantagens e desvantagens
# Bom: É fácil de usar e funciona bem em muitos casos.
# Ruim: Pode gastar muito tempo explorando coisas que não são tão boas no início.
#
# Exemplo prático
# Imagine que você tem 3 sabores de sorvete: baunilha, morango e limão. Você começa sem saber qual é o melhor. Cada vez que prova um sabor, dá uma nota. A máquina (ou você) usa essas notas para decidir o que provar da próxima vez.

# %%
import random
import logging

# Configuração do logging
logging.basicConfig(level=logging.INFO, format='%(message)s')

# Passo 1: Definir os sabores de sorvete e as recompensas
sabores = ["Baunilha", "Morango", "Limão"]

# Recompensas simuladas para cada sabor (quanto gostamos deles)
recompensas_reais = {"Baunilha": 7, "Morango": 9, "Limão": 6}

# Passo 2: Inicializar as estimativas de recompensa e contadores
valores_estimados = {sabor: 0 for sabor in sabores}  # Valor médio estimado de cada sabor
contagem = {sabor: 0 for sabor in sabores}  # Quantas vezes provamos cada sabor
epsilon = 0.1  # Taxa de exploração (10%)

# Passo 3: Função para simular a recompensa de um sabor
def experimentar_sabor(sabor):
    # Retorna uma recompensa baseada no sabor real com um pouco de aleatoriedade
    recompensa = random.randint(recompensas_reais[sabor] - 2, recompensas_reais[sabor] + 2)
    logging.info(f"Recompensa real do sabor {sabor}: {recompensa}")
    return recompensa

# Passo 4: Rodar o algoritmo Epsilon Greedy
total_rodadas = 50

for rodada in range(total_rodadas):
    logging.info(f"\nRodada {rodada + 1}/{total_rodadas}")
    
    # Decidir se vamos explorar ou explorar
    if random.random() < epsilon:
        # Explorar: Escolher um sabor aleatório
        sabor_escolhido = random.choice(sabores)
        logging.info(f"Explorando: escolhemos aleatoriamente o sabor {sabor_escolhido}")
    else:
        # Explorar: Escolher o sabor com maior recompensa estimada
        sabor_escolhido = max(valores_estimados, key=valores_estimados.get)
        logging.info(f"Exploitando: escolhemos o sabor com maior valor estimado: {sabor_escolhido}")
    
    # Provar o sabor e obter a recompensa
    recompensa = experimentar_sabor(sabor_escolhido)
    
    # Atualizar as estimativas e contagem para o sabor escolhido
    contagem[sabor_escolhido] += 1
    valores_estimados[sabor_escolhido] += (recompensa - valores_estimados[sabor_escolhido]) / contagem[sabor_escolhido]
    
    logging.info(f"Nova estimativa de {sabor_escolhido}: {valores_estimados[sabor_escolhido]:.2f}")
    logging.info(f"Total de vezes que {sabor_escolhido} foi escolhido: {contagem[sabor_escolhido]}")

# Passo 5: Mostrar os resultados
logging.info("\nEstimativas finais de recompensa para cada sabor:")
for sabor, valor in valores_estimados.items():
    logging.info(f"{sabor}: {valor:.2f} (Provado {contagem[sabor]} vezes)")

# Determinar o sabor mais gostoso
melhor_sabor = max(valores_estimados, key=valores_estimados.get)
logging.info(f"\nO sabor mais gostoso é: {melhor_sabor} 🍦!")
# Out:
# Rodada 1/50
# Explorando: escolhemos aleatoriamente o sabor Limão
# Recompensa real do sabor Limão: 6
# Nova estimativa de Limão: 6.00
# Total de vezes que Limão foi escolhido: 1
#
# Rodada 2/50
# Exploitando: escolhemos o sabor com maior valor estimado: Limão
# Recompensa real do sabor Limão: 5
# Nova estimativa de Limão: 5.50
# Total de vezes que Limão foi escolhido: 2
#
# Rodada 3/50
# Exploitando: escolhemos o sabor com maior valor estimado: Limão
# Recompensa real do sabor Limão: 4
# Nova estimativa de Limão: 5.00
# Total de vezes que Limão foi escolhido: 3
#
# Rodada 4/50
# Exploitando: escolhemos o sabor com maior valor estimado: Limão
# Recompensa real do sabor Limão: 8
# Nova estimativa de Limão: 5.75
# Total de vezes que Limão foi escolhido: 4
#
# Rodada 5/50
# Explorando: escolhemos aleatoriamente o sabor Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.00
# Total de vezes que Baunilha foi escolhido: 1
#
# Rodada 6/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 7.50
# Total de vezes que Baunilha foi escolhido: 2
#
# Rodada 7/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.67
# Total de vezes que Baunilha foi escolhido: 3
#
# Rodada 8/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.50
# Total de vezes que Baunilha foi escolhido: 4
#
# Rodada 9/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.20
# Total de vezes que Baunilha foi escolhido: 5
#
# Rodada 10/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.17
# Total de vezes que Baunilha foi escolhido: 6
#
# Rodada 11/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.14
# Total de vezes que Baunilha foi escolhido: 7
#
# Rodada 12/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.00
# Total de vezes que Baunilha foi escolhido: 8
#
# Rodada 13/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.33
# Total de vezes que Baunilha foi escolhido: 9
#
# Rodada 14/50
# Explorando: escolhemos aleatoriamente o sabor Limão
# Recompensa real do sabor Limão: 4
# Nova estimativa de Limão: 5.40
# Total de vezes que Limão foi escolhido: 5
#
# Rodada 15/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.20
# Total de vezes que Baunilha foi escolhido: 10
#
# Rodada 16/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.45
# Total de vezes que Baunilha foi escolhido: 11
#
# Rodada 17/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.33
# Total de vezes que Baunilha foi escolhido: 12
#
# Rodada 18/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.23
# Total de vezes que Baunilha foi escolhido: 13
#
# Rodada 19/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.43
# Total de vezes que Baunilha foi escolhido: 14
#
# Rodada 20/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 7
# Nova estimativa de Baunilha: 6.47
# Total de vezes que Baunilha foi escolhido: 15
#
# Rodada 21/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.38
# Total de vezes que Baunilha foi escolhido: 16
#
# Rodada 22/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 7
# Nova estimativa de Baunilha: 6.41
# Total de vezes que Baunilha foi escolhido: 17
#
# Rodada 23/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 8
# Nova estimativa de Baunilha: 6.50
# Total de vezes que Baunilha foi escolhido: 18
#
# Rodada 24/50
# Explorando: escolhemos aleatoriamente o sabor Limão
# Recompensa real do sabor Limão: 7
# Nova estimativa de Limão: 5.67
# Total de vezes que Limão foi escolhido: 6
#
# Rodada 25/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.63
# Total de vezes que Baunilha foi escolhido: 19
#
# Rodada 26/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 8
# Nova estimativa de Baunilha: 6.70
# Total de vezes que Baunilha foi escolhido: 20
#
# Rodada 27/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 8
# Nova estimativa de Baunilha: 6.76
# Total de vezes que Baunilha foi escolhido: 21
#
# Rodada 28/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 5
# Nova estimativa de Baunilha: 6.68
# Total de vezes que Baunilha foi escolhido: 22
#
# Rodada 29/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.78
# Total de vezes que Baunilha foi escolhido: 23
#
# Rodada 30/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.75
# Total de vezes que Baunilha foi escolhido: 24
#
# Rodada 31/50
# Exploitando: escolhemos o sabor com maior valor estimado: Baunilha
# Recompensa real do sabor Baunilha: 6
# Nova estimativa de Baunilha: 6.72
# Total de vezes que Baunilha foi escolhido: 25
#
# Rodada 32/50
# Explorando: escolhemos aleatoriamente o sabor Morango
# Recompensa real do sabor Morango: 10
# Nova estimativa de Morango: 10.00
# Total de vezes que Morango foi escolhido: 1
#
# Rodada 33/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 11
# Nova estimativa de Morango: 10.50
# Total de vezes que Morango foi escolhido: 2
#
# Rodada 34/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 7
# Nova estimativa de Morango: 9.33
# Total de vezes que Morango foi escolhido: 3
#
# Rodada 35/50
# Explorando: escolhemos aleatoriamente o sabor Limão
# Recompensa real do sabor Limão: 6
# Nova estimativa de Limão: 5.71
# Total de vezes que Limão foi escolhido: 7
#
# Rodada 36/50
# Explorando: escolhemos aleatoriamente o sabor Baunilha
# Recompensa real do sabor Baunilha: 9
# Nova estimativa de Baunilha: 6.81
# Total de vezes que Baunilha foi escolhido: 26
#
# Rodada 37/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 10
# Nova estimativa de Morango: 9.50
# Total de vezes que Morango foi escolhido: 4
#
# Rodada 38/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 9
# Nova estimativa de Morango: 9.40
# Total de vezes que Morango foi escolhido: 5
#
# Rodada 39/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 10
# Nova estimativa de Morango: 9.50
# Total de vezes que Morango foi escolhido: 6
#
# Rodada 40/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 8
# Nova estimativa de Morango: 9.29
# Total de vezes que Morango foi escolhido: 7
#
# Rodada 41/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 11
# Nova estimativa de Morango: 9.50
# Total de vezes que Morango foi escolhido: 8
#
# Rodada 42/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 10
# Nova estimativa de Morango: 9.56
# Total de vezes que Morango foi escolhido: 9
#
# Rodada 43/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 11
# Nova estimativa de Morango: 9.70
# Total de vezes que Morango foi escolhido: 10
#
# Rodada 44/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 7
# Nova estimativa de Morango: 9.45
# Total de vezes que Morango foi escolhido: 11
#
# Rodada 45/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 10
# Nova estimativa de Morango: 9.50
# Total de vezes que Morango foi escolhido: 12
#
# Rodada 46/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 8
# Nova estimativa de Morango: 9.38
# Total de vezes que Morango foi escolhido: 13
#
# Rodada 47/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 7
# Nova estimativa de Morango: 9.21
# Total de vezes que Morango foi escolhido: 14
#
# Rodada 48/50
# Explorando: escolhemos aleatoriamente o sabor Morango
# Recompensa real do sabor Morango: 7
# Nova estimativa de Morango: 9.07
# Total de vezes que Morango foi escolhido: 15
#
# Rodada 49/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 7
# Nova estimativa de Morango: 8.94
# Total de vezes que Morango foi escolhido: 16
#
# Rodada 50/50
# Exploitando: escolhemos o sabor com maior valor estimado: Morango
# Recompensa real do sabor Morango: 9
# Nova estimativa de Morango: 8.94
# Total de vezes que Morango foi escolhido: 17
#
# Estimativas finais de recompensa para cada sabor:
# Baunilha: 6.81 (Provado 26 vezes)
# Morango: 8.94 (Provado 17 vezes)
# Limão: 5.71 (Provado 7 vezes)
#
# O sabor mais gostoso é: Morango 🍦!

# %%
import random
import logging

# Configuração do logging para mostrar informações detalhadas
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(message)s')

# Lista de sabores de sorvete
sabores = ["chocolate", "baunilha", "morango"]

# Número de vezes que cada sabor foi escolhido e as recompensas acumuladas
num_escolhas = {sabor: 0 for sabor in sabores}
recompensas = {sabor: 0 for sabor in sabores}

# Parâmetro epsilon para controle da exploração
epsilon = 0.1

# Função para simular a recompensa de um sabor de sorvete
def simular_recompensa(sabor):
    if sabor == "chocolate":
        return random.uniform(0.7, 1.0)  # Chocolate é o mais popular
    elif sabor == "baunilha":
        return random.uniform(0.5, 0.8)
    elif sabor == "morango":
        return random.uniform(0.3, 0.6)

# Função para escolher o sabor com a maior recompensa média até agora
def escolher_melhor_sabor():
    melhor_sabor = max(sabores, key=lambda sabor: recompensas[sabor] / num_escolhas[sabor] if num_escolhas[sabor] > 0 else 0)
    return melhor_sabor

# Simulação de 50 escolhas
num_rodadas = 50
for rodada in range(1, num_rodadas + 1):
    if random.random() < epsilon:
        # Explorar: escolher um sabor aleatório
        sabor_escolhido = random.choice(sabores)
        logging.info(f"Rodada {rodada}: Explorando! Escolhendo um sabor aleatório: {sabor_escolhido}")
    else:
        # Aproveitar: escolher o melhor sabor conhecido
        sabor_escolhido = escolher_melhor_sabor()
        logging.info(f"Rodada {rodada}: Aproveitando! Escolhendo o melhor sabor conhecido: {sabor_escolhido}")

    # Simular a recompensa e atualizar os registros
    recompensa = simular_recompensa(sabor_escolhido)
    num_escolhas[sabor_escolhido] += 1
    recompensas[sabor_escolhido] += recompensa

    logging.info(f"Rodada {rodada}: Recompensa obtida: {recompensa:.2f}")

# Exibir os resultados finais
logging.info("Resultados finais:")
for sabor in sabores:
    media_recompensa = recompensas[sabor] / num_escolhas[sabor] if num_escolhas[sabor] > 0 else 0
    logging.info(f"{sabor}: escolhido {num_escolhas[sabor]} vezes, recompensa média = {media_recompensa:.2f}")
# Out:
# Rodada 1: Aproveitando! Escolhendo o melhor sabor conhecido: chocolate
# Rodada 1: Recompensa obtida: 0.82
# Rodada 2: Aproveitando! Escolhendo o melhor sabor conhecido: chocolate
# Rodada